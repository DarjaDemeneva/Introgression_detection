# %%
import seaborn as sns 
import pandas as pd

# %%
df = pd.read_pickle("pos_ct_param_file.pkl")
# Out:
#         state_names  starting_probabilities  \
# ind_ID
# HG00452       Human                 0.95297
# HG00452     Archaic                 0.04703
#
#                                          transitions  emissions   ind_ID  pop
# ind_ID
# HG00452  [0.9987354635477811, 0.0012645364522180002]   0.027986  HG00452  CHS
# HG00452   [0.025623412739000002, 0.9743765872609991]   0.342367  HG00452  CHS

# %%
df
# Out:
#         state_names  starting_probabilities  \
# ind_ID
# HG00452       Human                0.952970
# HG00452     Archaic                0.047030
# HG00115       Human                0.958491
# HG00115     Archaic                0.041509
# HG00451       Human                0.954009
# ...             ...                     ...
# HG00428     Archaic                0.047252
# HG00108       Human                0.958092
# HG00108     Archaic                0.041908
# HG00105       Human                0.958715
# HG00105     Archaic                0.041285
#
#                                          transitions  emissions   ind_ID  pop
# ind_ID
# HG00452  [0.9987354635477811, 0.0012645364522180002]   0.027986  HG00452  CHS
# HG00452   [0.025623412739000002, 0.9743765872609991]   0.342367  HG00452  CHS
# HG00115      [0.9988912527860271, 0.001108747213972]   0.027519  HG00115  GBR
# HG00115        [0.02560236441461, 0.974397635585389]   0.340643  HG00115  GBR
# ...

# %%
starting_prob_H = sns.boxplot(data=df[df["state_names"] == 'Human'], x="pop", y="starting_probabilities")

print(starting_prob_H)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
starting_prob_A = sns.boxplot(data=df[df["state_names"] == 'Archaic'], x="pop", y="starting_probabilities")

print(starting_prob_A)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
emissions_H = sns.boxplot(data=df[df['state_names']=='Human'], x="pop", y="emissions")
print(emissions_H)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
emissions_A = sns.boxplot(data=df[df['state_names']=='Archaic'], x="pop", y="emissions")
print(emissions_A)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
sns.pairplot(df[df['state_names']=='Human'], hue='pop')
# Out:
# /home/darja/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df[df['state_names']=='Archaic'], hue='pop')
# Out:
# /home/darja/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
new_df = df["transitions"].apply(pd.Series)
new_df["pop"] = df['pop']
new_df['state_names'] = df['state_names']
new_df.columns = ["transition_to_Human", "transition_to_Archaic", 'pop', 'state_names']
# Out:
#          transition_to_Human  transition_to_Archaic  pop state_names
# ind_ID
# HG00452             0.998735               0.001265  CHS       Human
# HG00452             0.025623               0.974377  CHS     Archaic

# %%
new_df
# Out:
#          transition_to_Human  transition_to_Archaic  pop state_names
# ind_ID
# HG00452             0.998735               0.001265  CHS       Human
# HG00452             0.025623               0.974377  CHS     Archaic
# HG00115             0.998891               0.001109  GBR       Human
# HG00115             0.025602               0.974398  GBR     Archaic
# HG00451             0.998794               0.001206  CHS       Human
# ...                      ...                    ...  ...         ...
# HG00428             0.025488               0.974512  CHS     Archaic
# HG00108             0.998860               0.001140  GBR       Human
# HG00108             0.026063               0.973937  GBR     Archaic
# HG00105             0.998884               0.001116  GBR       Human
# HG00105             0.025916               0.974084  GBR     Archaic
#
# [80 rows x 4 columns]

# %%
sns.pairplot(new_df[new_df['state_names']=='Human'], hue='pop')
# Out:
# /home/darja/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(new_df[new_df['state_names']=='Archaic'], hue='pop')
# Out:
# /home/darja/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
transitions_HH = sns.boxplot(data=new_df[new_df['state_names']=='Human'], x='state_names', y='transition_to_Human', hue='pop')

print(transitions_HH)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
transitions_AA = sns.boxplot(data=new_df[new_df['state_names']=='Archaic'], x='state_names', y='transition_to_Archaic', hue='pop')
print(transitions_AA)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
transitions_AH = sns.boxplot(data=new_df[new_df['state_names']=='Archaic'], x='state_names', y='transition_to_Human', hue='pop')

print(transitions_AH)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
transitions_HA = sns.boxplot(data=new_df[new_df['state_names']=='Human'], x='state_names', y='transition_to_Archaic', hue='pop')

print(transitions_HA)
# Out:
# Axes(0.125,0.11;0.775x0.77)
