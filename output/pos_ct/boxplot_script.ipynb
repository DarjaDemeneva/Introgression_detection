# %%
import seaborn as sns 
import pandas as pd

# %%
df = open("parameters_file.txt", "r")
df1 = pd.read_csv(df, sep='\t')
print(df1)

df_plot = sns.boxplot(df1)

print(df_plot)
# Out:
#    Individual_ID  Unnamed: 1 state_names  starting_probabilities  \
# 0        HG00096           0       Human                0.969096
# 1        HG00096           1     Archaic                0.030904
# 2        HG00097           0       Human                0.969734
# 3        HG00097           1     Archaic                0.030266
# 4        HG00099           0       Human                0.969730
# 5        HG00099           1     Archaic                0.030270
# 6        HG00100           0       Human                0.970007
# 7        HG00100           1     Archaic                0.029993
# 8        HG00101           0       Human                0.968619
# 9        HG00101           1     Archaic                0.031381
# 10       HG00403           0       Human                0.960841
# 11       HG00403           1     Archaic                0.039159
# 12       HG00404           0       Human                0.962212
# ...
